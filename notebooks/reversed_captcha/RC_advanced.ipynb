# %% [markdown]
# # Selenium web scraping
# - 1: Get list of all labels
# - 2: Get list of all endpoints for all labels
# - 3: Do all requests for first image.
# - 4: Sort this list
# - 5: take the highest x (20?) requests and send all other images to that endpoint
# - 6: sort that list, which is now the highest?
# optional: automatic send the answer?
#
# - 7: if wrong, ping endpoint each minute untill other value (so rest) and do the same again

# %% [markdown]
# # 1: Get list of all labels

# %%
# Get all labels to print
import json

# return the wordnetsysnet
def get_all_labels_name():
    f = open(r"C:\Users\niels\Downloads\Reverse Captcha\labels.json")
  
    # returns JSON object as 
    # a dictionary
    data = json.load(f)

    labels_to_get = []
    for i in range(0, 1000): # because 1000 records
        #print(data[i]['label'])
        labels_to_get.append(data[i]['label'])
    f.close()
    #print(labels_to_get)
    return labels_to_get

# return the wordnetsysnet
def get_all_labels_wordnetSynset():
    f = open(r"C:\Users\niels\Downloads\Reverse Captcha\labels.json")
  
    # returns JSON object as 
    # a dictionary
    data = json.load(f)

    labels_to_get = []
    for i in range(0, 1000): # because 1000 records
        #print(data[i]['label'])
        labels_to_get.append(data[i]['wordnetSynset'])
    f.close()
    #print(labels_to_get)
    return labels_to_get

wordnetSynset_labels = get_all_labels_wordnetSynset()

# %% [markdown]
# # 2: Get list of all endpoints for all labels

# %%
# create list of all image names per category (will be faster then calling os for each request)
import os

class ImageLocationItem:
    label: int
    location1: str
    location2: str
    location3: str
    location4: str
    location5: str
    def __init__(self):
        self.location1 = ""
        self.location2 = ""
        self.location4 = ""
        self.location3 = ""
        self.location5 = ""
    def PrintItem(self):
        print("for " + str(self.label))
        print("1: " + self.location1)
        print("2: " + self.location2)
        print("3: " + self.location3)
        print("4: " + self.location4)
        #print("5: " + self.location5) # most images only have max of 4 images available in directory
    def GetLocationList(self):
        locations = []
        if self.location1 != None:
            locations.append(self.location1)
        if self.location2 != None:
            locations.append(self.location2)
        if self.location3 != None:
            locations.append(self.location3)
        if self.location4 != None:
            locations.append(self.location4)
        return locations

item_labels = get_all_labels_name()
image_location_list = []
for x in range(0, 1000):
    item_name = item_labels[x]
    
    obj = ImageLocationItem()
    obj.label = item_name
    
    directory_in_str = "C:\ReversedCaptcha\hd-label-images\\" + item_name
    directory = os.fsencode(directory_in_str)
    
    currentIndex = 1
    for file in os.listdir(directory):
        filename = os.fsdecode(file)
         
        if currentIndex == 1:
            obj.location1 = directory_in_str + "\\" + filename # + directory? check when first time debugging
        if currentIndex == 2:
            obj.location2 = directory_in_str + "\\" + filename # + directory? check when first time debugging
        if currentIndex == 3:
            obj.location3 = directory_in_str + "\\" + filename # + directory? check when first time debugging
        if currentIndex == 4:
            obj.location4 = directory_in_str + "\\" + filename # + directory? check when first time debugging
        if currentIndex == 5:
            obj.location5 = directory_in_str + "\\" + filename # + directory? check when first time debugging
        
        if currentIndex == 6:
            break
        
        currentIndex += 1
    image_location_list.append(obj)

# Testing
#image_location_list[400].PrintItem()
#x = 1000
#for i in range(0, x): # if this does not fail, all images have at least 4 images 
    #image_location_list[i].PrintItem()

# %% [markdown]
# # 3: Do all requests for first image.

# %%
# image_location_list contains all image location
# item_labels contains all labels

import requests
import concurrent
from concurrent.futures import ThreadPoolExecutor

loops = range(0, 1000)

failed_labels = []
failed_indexes = []
dirs_to_remove = []

real_url = 'https://europe-west1-coding-challenge-platform.cloudfunctions.net/ctf-reverse-captcha-5736741495373824'

def get_label_info(index):
    # Prepare request to send for index
    label = item_labels[index]
    #image_path = "C:\ReversedCaptcha\Images\itemname\itemname1.jpg".replace("itemname", label) # non HD images
    image_path = image_location_list[index].location1 # HD images
    
    # Open image to send along
    with open(image_path, "rb") as file:
        files = {'file': file}
        
        # Send the request
        response = requests.post(real_url, headers={"Authorization":"{5736741495373824}"}, files=files)
        
        #print(json_response)

        json_response = None
        if response.status_code == 200:
            json_response = response.json()
            #print(json_response["result"] + " " + label + " Successfully retrieved label " + label) BIG_INFO
        elif response.status_code == 422:
            dirs_to_remove.append(image_path) # image is not sendable
        else:
            failed_labels.append(label)
            failed_indexes.append(index)
            #print("Something went wrong for label " + label + " with status code " + str(response.status_code)) BIG_INFO
        
        # Do something with the response
        json_response['label'] = label # add the label to the response data so we can look it up later
        json_response['index'] = index
        
    return json_response

def get_result_for_each_first_image():
    print("Getting results...")
    failed_labels = [] # global info lists to keep track off
    failed_indexes = []
    dirs_to_remove = []
    
    result_list = []
    test_url = 'http://localhost:3000/users'
    real_url = 'https://europe-west1-coding-challenge-platform.cloudfunctions.net/ctf-reverse-captcha-5736741495373824'
    threads = 23
    
    with ThreadPoolExecutor(max_workers=threads) as executor:
        future_to_url = {executor.submit(get_label_info, char) for char in loops}

        for future in concurrent.futures.as_completed(future_to_url):
            try:
                data = future.result()
                #print(data)
                result_list.append(data)
                #print(data['status'])
                #print(data['result'])
            except Exception as e:
                #print("Something went wrong " + str(e))
                pass
    print("Got all single results. Total of " + str(len(result_list)) + " records.")
    return result_list


            
def remove_image_from_dir(directory):
    #print("deleting " + directory)
    os.remove(directory)

# %% [markdown]
# # 4: Sort this list with first requests

# %%
def get_n_highest_of_list(result_list, n):
    print("sorting list of results with " +  str(len(result_list)) + " elements")

    result_list.sort(key=lambda x: x["result"])
    result_list.reverse()
    
    # print top x from the bottom (sort does sort )
    for i in range(0, 100):
        print(result_list[i])
        
    return result_list[0:n]

def sort_advanced_list(advanced_list):
    advanced_list.sort(key=lambda x: x.average_top_three)
    advanced_list.reverse()
    return advanced_list

# %%
# Remove false directories
def remove_false_dirs():
    print("n dirs to remove: " + str(len(dirs_to_remove)))
    for d in dirs_to_remove:
        remove_image_from_dir(d)

# %% [markdown]
# # 5: take the highest x (20?) requests and send all other images to that endpoint

# %%
class AdvancedLabelData:
    label_index: int
    label_name: str
    max_value: float
    min_value: float
    average_total: float
    average_top_three: float
    total_dirs: int
    def LogThis(self):
        print("label_name: " + self.label_name)
        print("label_index: " + str(self.label_index))
        print("max_value: " + str(self.max_value))
        print("min_value: " + str(self.min_value))
        print("average_total: " + str(self.average_total))
        print("average_top_three: " + str(self.average_top_three))
        print("total_dirs: " + str(self.total_dirs))
        print("--------------------")

def get_advanced_label_data(label_name, index):
    all_results = get_all_label_results(label_name, index)
    #print(all_results)
    all_results_as_floats = str_list_to_float(all_results)
    all_results_as_floats.sort(reverse=True)
    
    advanced_data = AdvancedLabelData()
    
    advanced_data.label_index = index
    advanced_data.label_name = label_name
    advanced_data.total_dirs = len(all_results)
    
    advanced_data.max_value = all_results_as_floats[0]
    advanced_data.min_value = all_results_as_floats[len(all_results_as_floats)-1]
    
    # if 3+ records are in response set
    if len(all_results) >= 3:
        advanced_data.average_total = calc_average_total(all_results_as_floats)
        advanced_data.average_top_three = calc_average_total(all_results_as_floats[0:3])
    
    # if 2 records
    if len(all_results) == 2:
        advanced_data.average_total = calc_average_total(all_results_as_floats)
        advanced_data.average_top_three = calc_average_total(all_results_as_floats[0:2])
    
    # if only 1 is in response set
    if len(all_results) == 1:
        advanced_data.average_total = all_results_as_floats[0]
        advanced_data.average_top_three = None
    
    return advanced_data

def get_advanced_label_data_by_index(index):
    label_name = item_labels[index]
    
    all_results = get_all_label_results(label_name, index)
    
    all_results_as_floats = str_list_to_float(all_results)
    all_results_as_floats.sort(reverse=True)
    advanced_data = AdvancedLabelData()
    
    advanced_data.label_index = index
    advanced_data.label_name = label_name
    advanced_data.total_dirs = len(all_results)
    
    advanced_data.max_value = all_results_as_floats[0]
    advanced_data.min_value = all_results_as_floats[len(all_results_as_floats)-1]
    
    # if 3+ records are in response set
    if len(all_results) >= 3:
        advanced_data.average_total = calc_average_total(all_results_as_floats)
        advanced_data.average_top_three = calc_average_total(all_results_as_floats[0:3])
   
    # if 2 records
    if len(all_results) == 2:
        advanced_data.average_total = calc_average_total(all_results_as_floats)
        advanced_data.average_top_three = calc_average_total(all_results_as_floats[0:2])
    
    # if only 1 is in response set
    if len(all_results) == 1:
        advanced_data.average_total = all_results_as_floats[0]
        advanced_data.average_top_three = None
    
    return advanced_data

def get_all_label_results(label_name, index):
    label_image_dirs = image_location_list[index].GetLocationList()
    all_label_values = []
    for image_dir in label_image_dirs:
        try:
            resp = get_info_by_image_path(image_dir)
            all_label_values.append(resp["result"][0:4])
        except Exception as e:
            print(":-( " + str(e))
    return all_label_values
    
    
def get_info_by_image_path(image_path):
    # Open image to send along
    with open(image_path, "rb") as file:
        files = {'file': file}
        
        # Send the request
        response = requests.post(real_url, headers={"Authorization":"{5736741495373824}"}, files=files)
        json_response = response.json()
        #print(json_response)

        if response.status_code == 422:
            dirs_to_remove.append(image_path) # image is not sendable   
    return json_response

def str_list_to_float(str_list):
    n_list = []
    
    for s in str_list:
        try:
            n_list.append(float(s))
        except:
            #print("not a float (prob 'Could not parse... error because image cant send correctly'")
            pass
    return n_list

def calc_average_total(number_list):
    total = 0
    
    for number in number_list:
        total += number

    return total / len(number_list)

# %%
def get_indexes_from_list(the_list):
    index_list = []
    
    for rec in the_list:
        index_list.append(rec["index"])
    
    return index_list

def get_advanced_top_n_list(top_n, all_results):
    first_batch = get_result_for_each_first_image()
    list_top = get_n_highest_of_list(all_results, top_n)

    for record in list_top:
        label_name = record['label']
        index = item_labels.index(label_name)
        a = get_advanced_label_data(label_name, index)
        a.LogThis()
        
def get_adnvanced_data_by_index_list(index_list):
    advanced_result_list = []
    real_url = 'https://europe-west1-coding-challenge-platform.cloudfunctions.net/ctf-reverse-captcha-5736741495373824'
    threads = 23
    
    with ThreadPoolExecutor(max_workers=threads) as executor:
        future_to_url = {executor.submit(get_advanced_label_data_by_index, char) for char in index_list}

        for future in concurrent.futures.as_completed(future_to_url):
            try:
                data = future.result()
                #print(data)
                advanced_result_list.append(data)
                #print(data['status'])
                #print(data['result'])
            except Exception as e:
                print("Something went wrong " + str(e))    
    return advanced_result_list

# %% [markdown]
# # 6 send request and check if okay

# %%
def send_guess(index):
    label_wordnetsyns = wordnetSynset_labels[index]
    label_name = item_labels[index]
    print("sending guess for label " + label_name + " with synsnet " + label_wordnetsyns)
    return guess_answer(label_name, label_wordnetsyns)
                
def guess_answer(label, wordnet):
    url = "https://europe-west1-coding-challenge-platform.cloudfunctions.net/ctf-reverse-captcha-5736741495373824/answer"
    r = requests.post(url, headers={"Authorization":"{5736741495373824}"}, json={"label": label, "wordnetSynset": wordnet})

    if r.status_code == 500:
        print("Guess was wrong. Status code: " + str(r.status_code) + ". With message: " + str(r.content))
    else:
        print("YOOO, BIG ")
        print(r.status_code)
        print(r.content)
    return r.status_code != 500
    
def calc_labels_and_send_request(print_results):
    first_batch = get_result_for_each_first_image()
    highest_from_list = get_n_highest_of_list(first_batch, 50)
    index_list = get_indexes_from_list(highest_from_list)
    adv_results = get_adnvanced_data_by_index_list(index_list)
    sorted_adv_results = sort_advanced_list(adv_results)

    sorted_adv_results[0].LogThis()
    
    if print_results:
        for res in sorted_adv_results:
            res.LogThis()
            
    answer_correct = send_guess(sorted_adv_results[0].label_index)
    print("answer correct: " + str(answer_correct))
    return answer_correct

# %% [markdown]
# # 7: if wrong, ping endpoint each minute untill other value (so rest) and do the same again

# %%
import requests
import time
from datetime import datetime

def send_static_request_with_same_image_always():
    # Prepare request to send for index
    label = "n09193705"
    image_path = "C:\ReversedCaptcha\hd-label-images\\accordion\\accordion1.jpg"
    real_url = 'https://europe-west1-coding-challenge-platform.cloudfunctions.net/ctf-reverse-captcha-5736741495373824'
    
    # Open image to send along
    with open(image_path, "rb") as file:
        files = {'file': file}
        
        # Send the request
        response = requests.post(real_url, headers={"Authorization":"{5736741495373824}"}, files=files)
        print("Static ping " + response.json()['result'])
        
        # Do something with the response
        json_response = response.json()
        json_response['label'] = label # add the label to the response data so we can look it up later
    return json_response

def send_request_and_get_response():
    r = send_static_request_with_same_image_always()
    return r['result']

current_result = ""
def ping_untill_other_response():
    result = send_request_and_get_response()
    current_result = result[0:6]
    
    for x in range(0, 60):
        result2 = send_request_and_get_response()
        compare_result = result2[0:6]
        
        if compare_result != current_result:
            return True
        time.sleep(20) # wait 20 seconds before trying again
        
    # If this returns false, something went completely wrong because in 30 minutes nothing changed?
    return False

# %%
def lets_do_this():
    stop_looping = False
    
    while stop_looping == False:
        ping_untill_other_response()
        correct = calc_labels_and_send_request(False)
        if correct:
            stop_looping = True

# %%
lets_do_this()
# Out:
# Static ping 0.00017700763
# Static ping 0.00017700763
# Static ping 0.00017700763
# Static ping 0.000177008
# Static ping 0.000177008
# Static ping 0.000177008
# Static ping 0.00017700763
# Static ping 0.00017700763
# Static ping 0.000177008
# Static ping 0.00017700763
# Static ping 0.00017700763
# Static ping 0.000177008
# Static ping 0.00017700763
# Static ping 0.00017700763
# Static ping 0.00017700763
# Static ping 0.00017700763
# Static ping 0.00017700763
# Static ping 0.00017700763
# Static ping 2.9880894e-05
# Getting results...
# Got all single results. Total of 974 records.
# sorting list of results with 974 elements
# {'status': 'ok', 'result': '9.996833e-06', 'label': 'Persian_cat', 'index': 283}
# {'status': 'ok', 'result': '9.993992e-06', 'label': 'tiger_shark', 'index': 3}
# {'status': 'ok', 'result': '9.96658e-05', 'label': 'revolver', 'index': 763}
# {'status': 'ok', 'result': '9.965671e-06', 'label': 'golfcart', 'index': 575}
# {'status': 'ok', 'result': '9.944361e-06', 'label': 'projector', 'index': 745}
# {'status': 'ok', 'result': '9.913106e-05', 'label': 'hamper', 'index': 588}
# {'status': 'ok', 'result': '9.879785e-05', 'label': 'ladle', 'index': 618}
# {'status': 'ok', 'result': '9.863349e-06', 'label': 'armadillo', 'index': 363}
# {'status': 'ok', 'result': '9.8496814e-05', 'label': 'spindle', 'index': 816}
# {'status': 'ok', 'result': '9.847422e-05', 'label': 'guillotine', 'index': 583}
# {'status': 'ok', 'result': '9.831673e-05', 'label': 'church', 'index': 497}
# {'status': 'ok', 'result': '9.80535e-05', 'label': 'broccoli', 'index': 937}
# {'status': 'ok', 'result': '9.803853e-05', 'label': 'confectionery', 'index': 509}
# {'status': 'ok', 'result': '9.733961e-05', 'label': 'swimming_trunks', 'index': 842}
# {'status': 'ok', 'result': '9.7225575e-06', 'label': 'triumphal_arch', 'index': 873}
# {'status': 'ok', 'result': '9.674267e-06', 'label': 'handkerchief', 'index': 591}
# {'status': 'ok', 'result': '9.580233e-05', 'label': 'loupe', 'index': 633}
# {'status': 'ok', 'result': '9.573246e-05', 'label': 'Eskimo_dog', 'index': 248}
# {'status': 'ok', 'result': '9.567109e-06', 'label': 'palace', 'index': 698}
# {'status': 'ok', 'result': '9.563254e-05', 'label': 'sliding_door', 'index': 799}
# {'status': 'ok', 'result': '9.545657e-08', 'label': 'slot', 'index': 800}
# {'status': 'ok', 'result': '9.5343904e-07', 'label': 'bee_eater', 'index': 92}
# {'status': 'ok', 'result': '9.516649e-06', 'label': 'rhinoceros_beetle', 'index': 306}
# {'status': 'ok', 'result': '9.482163e-05', 'label': 'brambling', 'index': 10}
# {'status': 'ok', 'result': '9.331523e-05', 'label': 'Newfoundland', 'index': 256}
# {'status': 'ok', 'result': '9.330005e-05', 'label': 'titi', 'index': 380}
# {'status': 'ok', 'result': '9.316256e-07', 'label': 'binoculars', 'index': 447}
# {'status': 'ok', 'result': '9.265483e-05', 'label': 'cocker_spaniel', 'index': 219}
# {'status': 'ok', 'result': '9.250001e-05', 'label': 'tiger', 'index': 292}
# {'status': 'ok', 'result': '9.230921e-05', 'label': 'lycaenid', 'index': 326}
# {'status': 'ok', 'result': '9.2228165e-06', 'label': 'knot', 'index': 616}
# {'status': 'ok', 'result': '9.209763e-05', 'label': 'ground_beetle', 'index': 302}
# {'status': 'ok', 'result': '9.140527e-05', 'label': 'basketball', 'index': 430}
# {'status': 'ok', 'result': '9.136998e-06', 'label': 'stage', 'index': 819}
# {'status': 'ok', 'result': '9.0742915e-06', 'label': 'assault_rifle', 'index': 413}
# {'status': 'ok', 'result': '9.041951e-05', 'label': 'macaw', 'index': 88}
# {'status': 'ok', 'result': '9.0088515e-06', 'label': 'half_track', 'index': 586}
# {'status': 'ok', 'result': '9.004683e-06', 'label': 'suit', 'index': 834}
# {'status': 'ok', 'result': '9.001323e-05', 'label': 'washbasin', 'index': 896}
# {'status': 'ok', 'result': '9.001129e-05', 'label': 'langur', 'index': 374}
# {'status': 'ok', 'result': '8.976202e-05', 'label': 'polecat', 'index': 358}
# {'status': 'ok', 'result': '8.8944944e-05', 'label': 'lesser_panda', 'index': 387}
# {'status': 'ok', 'result': '8.834746e-06', 'label': 'scoreboard', 'index': 781}
# {'status': 'ok', 'result': '8.824822e-05', 'label': 'damselfly', 'index': 320}
# {'status': 'ok', 'result': '8.823105e-05', 'label': 'pizza', 'index': 963}
# {'status': 'ok', 'result': '8.812601e-06', 'label': 'sewing_machine', 'index': 786}
# {'status': 'ok', 'result': '8.776753e-05', 'label': 'tabby', 'index': 281}
# {'status': 'ok', 'result': '8.769448e-06', 'label': 'shoe_shop', 'index': 788}
# {'status': 'ok', 'result': '8.691387e-06', 'label': 'earthstar', 'index': 995}
# {'status': 'ok', 'result': '8.652885e-05', 'label': 'wool', 'index': 911}
# {'status': 'ok', 'result': '8.625652e-05', 'label': 'gazelle', 'index': 353}
# {'status': 'ok', 'result': '8.610546e-05', 'label': 'espresso_maker', 'index': 550}
# {'status': 'ok', 'result': '8.604615e-06', 'label': 'volcano', 'index': 980}
# {'status': 'ok', 'result': '8.545921e-06', 'label': 'military_uniform', 'index': 652}
# {'status': 'ok', 'result': '8.458339e-06', 'label': 'desk', 'index': 526}
# {'status': 'ok', 'result': '8.442434e-05', 'label': 'sulphur_butterfly', 'index': 325}
# {'status': 'ok', 'result': '8.387048e-06', 'label': 'broom', 'index': 462}
# {'status': 'ok', 'result': '8.385934e-05', 'label': 'snail', 'index': 113}
# {'status': 'ok', 'result': '8.348919e-05', 'label': 'orangutan', 'index': 365}
# {'status': 'ok', 'result': '8.341025e-06', 'label': 'hammer', 'index': 587}
# {'status': 'ok', 'result': '8.332803e-05', 'label': 'spatula', 'index': 813}
# {'status': 'ok', 'result': '8.320198e-06', 'label': 'soup_bowl', 'index': 809}
# {'status': 'ok', 'result': '8.317996e-05', 'label': 'studio_couch', 'index': 831}
# {'status': 'ok', 'result': '8.305864e-05', 'label': 'submarine', 'index': 833}
# {'status': 'ok', 'result': '8.294397e-06', 'label': 'scorpion', 'index': 71}
# {'status': 'ok', 'result': '8.283562e-06', 'label': 'bearskin', 'index': 439}
# {'status': 'ok', 'result': '8.2674276e-05', 'label': 'komondor', 'index': 228}
# {'status': 'ok', 'result': '8.2672625e-05', 'label': 'Rhodesian_ridgeback', 'index': 159}
# {'status': 'ok', 'result': '8.260409e-05', 'label': 'Irish_wolfhound', 'index': 170}
# {'status': 'ok', 'result': '8.257464e-05', 'label': 'catamaran', 'index': 484}
# {'status': 'ok', 'result': '8.23775e-05', 'label': 'computer_keyboard', 'index': 508}
# {'status': 'ok', 'result': '8.2363265e-05', 'label': 'gas_pump', 'index': 571}
# {'status': 'ok', 'result': '8.208893e-05', 'label': 'monarch', 'index': 323}
# {'status': 'ok', 'result': '8.208486e-06', 'label': 'baseball', 'index': 429}
# {'status': 'ok', 'result': '8.194383e-05', 'label': 'quail', 'index': 85}
# {'status': 'ok', 'result': '8.1796503e-07', 'label': 'safety_pin', 'index': 772}
# {'status': 'ok', 'result': '8.166435e-06', 'label': 'analog_clock', 'index': 409}
# {'status': 'ok', 'result': '8.155767e-05', 'label': 'milk_can', 'index': 653}
# {'status': 'ok', 'result': '8.1188526e-05', 'label': 'sturgeon', 'index': 394}
# {'status': 'ok', 'result': '8.107684e-06', 'label': 'padlock', 'index': 695}
# {'status': 'ok', 'result': '8.072305e-05', 'label': 'corn', 'index': 987}
# {'status': 'ok', 'result': '8.0685175e-05', 'label': 'squirrel_monkey', 'index': 382}
# {'status': 'ok', 'result': '8.0306425e-05', 'label': 'bittern', 'index': 133}
# {'status': 'ok', 'result': '8.0209305e-05', 'label': 'sock', 'index': 806}
# {'status': 'ok', 'result': '8.013678e-05', 'label': 'American_chameleon', 'index': 40}
# {'status': 'ok', 'result': '7.990723e-05', 'label': 'fiddler_crab', 'index': 120}
# {'status': 'ok', 'result': '7.987575e-05', 'label': 'desktop_computer', 'index': 527}
# {'status': 'ok', 'result': '7.983184e-07', 'label': 'Loafer', 'index': 630}
# {'status': 'ok', 'result': '7.934877e-06', 'label': 'electric_guitar', 'index': 546}
# {'status': 'ok', 'result': '7.923938e-05', 'label': 'brass', 'index': 458}
# {'status': 'ok', 'result': '7.918551e-05', 'label': 'lipstick', 'index': 629}
# {'status': 'ok', 'result': '7.8817284e-05', 'label': 'tiger_beetle', 'index': 300}
# {'status': 'ok', 'result': '7.867223e-05', 'label': 'mitten', 'index': 658}
# {'status': 'ok', 'result': '7.854543e-06', 'label': 'mountain_tent', 'index': 672}
# {'status': 'ok', 'result': '7.843138e-05', 'label': 'refrigerator', 'index': 760}
# {'status': 'ok', 'result': '7.842905e-05', 'label': 'jay', 'index': 17}
# {'status': 'ok', 'result': '7.822601e-05', 'label': 'drilling_platform', 'index': 540}
# {'status': 'ok', 'result': '7.7858834e-07', 'label': 'dam', 'index': 525}
# {'status': 'ok', 'result': '7.7711535e-05', 'label': 'airliner', 'index': 404}
# {'status': 'ok', 'result': '7.767877e-05', 'label': 'odometer', 'index': 685}
# :-( [Errno 2] No such file or directory: ''
# Something went wrong could not convert string to float: 'Coul'
# Something went wrong could not convert string to float: 'Coul'
# :-( [Errno 2] No such file or directory: ''
# Something went wrong could not convert string to float: 'Coul'
# :-( [Errno 2] No such file or directory: ''
# Something went wrong could not convert string to float: 'Coul'
# :-( [Errno 2] No such file or directory: ''
# Something went wrong could not convert string to float: 'Coul'
# :-( [Errno 2] No such file or directory: ''
# Something went wrong could not convert string to float: 'Coul'
# Something went wrong could not convert string to float: 'Coul'
# Something went wrong could not convert string to float: 'Coul'
# Something went wrong could not convert string to float: 'Coul'
# label_name: earthstar
# label_index: 995
# max_value: 9.79
# min_value: 3.86
# average_total: 7.862499999999999
# average_top_three: 9.196666666666665
# total_dirs: 4
# --------------------
# sending guess for label earthstar with synsnet n13044778
# Guess was wrong. Status code: 500. With message: b'Error: could not handle the request\n'
# answer correct: False
# Static ping 2.9881012e-05
# Static ping 2.9881012e-05
# Static ping 2.9881012e-05
# Static ping 2.9880894e-05
# Getting results...
# Got all single results. Total of 992 records.
# sorting list of results with 992 elements
# {'status': 'ok', 'result': '9.996833e-06', 'label': 'Persian_cat', 'index': 283}
# {'status': 'ok', 'result': '9.994045e-06', 'label': 'tiger_shark', 'index': 3}
# {'status': 'ok', 'result': '9.9531135e-05', 'label': 'picket_fence', 'index': 716}
# {'status': 'ok', 'result': '9.8633745e-06', 'label': 'armadillo', 'index': 363}
# {'status': 'ok', 'result': '9.7716445e-05', 'label': 'crossword_puzzle', 'index': 918}
# {'status': 'ok', 'result': '9.727481e-06', 'label': 'sarong', 'index': 775}
# {'status': 'ok', 'result': '9.720108e-06', 'label': 'overskirt', 'index': 689}
# {'status': 'ok', 'result': '9.670802e-06', 'label': 'trifle', 'index': 927}
# {'status': 'ok', 'result': '9.5839285e-05', 'label': 'wine_bottle', 'index': 907}
# {'status': 'ok', 'result': '9.573248e-05', 'label': 'Eskimo_dog', 'index': 248}
# {'status': 'ok', 'result': '9.534426e-07', 'label': 'bee_eater', 'index': 92}
# {'status': 'ok', 'result': '9.516649e-06', 'label': 'rhinoceros_beetle', 'index': 306}
# {'status': 'ok', 'result': '9.489511e-05', 'label': 'submarine', 'index': 833}
# {'status': 'ok', 'result': '9.487861e-05', 'label': 'espresso', 'index': 967}
# {'status': 'ok', 'result': '9.482163e-05', 'label': 'brambling', 'index': 10}
# {'status': 'ok', 'result': '9.445341e-06', 'label': 'mixing_bowl', 'index': 659}
# {'status': 'ok', 'result': '9.407116e-05', 'label': 'pillow', 'index': 721}
# {'status': 'ok', 'result': '9.382544e-07', 'label': 'cleaver', 'index': 499}
# {'status': 'ok', 'result': '9.381742e-05', 'label': 'hoopskirt', 'index': 601}
# {'status': 'ok', 'result': '9.331532e-05', 'label': 'Newfoundland', 'index': 256}
# {'status': 'ok', 'result': '9.329972e-05', 'label': 'titi', 'index': 380}
# {'status': 'ok', 'result': '9.31622e-07', 'label': 'binoculars', 'index': 447}
# {'status': 'ok', 'result': '9.289628e-07', 'label': 'pick', 'index': 714}
# {'status': 'ok', 'result': '9.265483e-05', 'label': 'cocker_spaniel', 'index': 219}
# {'status': 'ok', 'result': '9.2643326e-08', 'label': 'fireboat', 'index': 554}
# {'status': 'ok', 'result': '9.260988e-05', 'label': 'revolver', 'index': 763}
# {'status': 'ok', 'result': '9.250001e-05', 'label': 'tiger', 'index': 292}
# {'status': 'ok', 'result': '9.230921e-05', 'label': 'lycaenid', 'index': 326}
# {'status': 'ok', 'result': '9.209763e-05', 'label': 'ground_beetle', 'index': 302}
# {'status': 'ok', 'result': '9.206572e-06', 'label': 'lemon', 'index': 951}
# {'status': 'ok', 'result': '9.206554e-06', 'label': 'soup_bowl', 'index': 809}
# {'status': 'ok', 'result': '9.197557e-06', 'label': 'radio_telescope', 'index': 755}
# {'status': 'ok', 'result': '9.185282e-06', 'label': 'fountain', 'index': 562}
# {'status': 'ok', 'result': '9.1609916e-05', 'label': 'coral_fungus', 'index': 991}
# {'status': 'ok', 'result': '9.15841e-05', 'label': 'thimble', 'index': 855}
# {'status': 'ok', 'result': '9.140527e-05', 'label': 'basketball', 'index': 430}
# {'status': 'ok', 'result': '9.107153e-05', 'label': 'mortar', 'index': 666}
# {'status': 'ok', 'result': '9.075439e-05', 'label': 'valley', 'index': 979}
# {'status': 'ok', 'result': '9.074315e-06', 'label': 'assault_rifle', 'index': 413}
# {'status': 'ok', 'result': '9.041951e-05', 'label': 'macaw', 'index': 88}
# {'status': 'ok', 'result': '9.038582e-08', 'label': 'vestment', 'index': 887}
# {'status': 'ok', 'result': '9.033493e-05', 'label': 'screen', 'index': 782}
# {'status': 'ok', 'result': '9.001104e-05', 'label': 'langur', 'index': 374}
# {'status': 'ok', 'result': '8.999011e-06', 'label': 'mousetrap', 'index': 674}
# {'status': 'ok', 'result': '8.976202e-05', 'label': 'polecat', 'index': 358}
# {'status': 'ok', 'result': '8.9236556e-07', 'label': 'nipple', 'index': 680}
# {'status': 'ok', 'result': '8.8944944e-05', 'label': 'lesser_panda', 'index': 387}
# {'status': 'ok', 'result': '8.89143e-06', 'label': 'screwdriver', 'index': 784}
# {'status': 'ok', 'result': '8.864136e-06', 'label': 'gasmask', 'index': 570}
# {'status': 'ok', 'result': '8.845167e-05', 'label': 'odometer', 'index': 685}
# {'status': 'ok', 'result': '8.824822e-05', 'label': 'damselfly', 'index': 320}
# {'status': 'ok', 'result': '8.78133e-05', 'label': 'guacamole', 'index': 924}
# {'status': 'ok', 'result': '8.776753e-05', 'label': 'tabby', 'index': 281}
# {'status': 'ok', 'result': '8.724867e-05', 'label': 'cauliflower', 'index': 938}
# {'status': 'ok', 'result': '8.659209e-05', 'label': 'hatchet', 'index': 596}
# {'status': 'ok', 'result': '8.643024e-05', 'label': 'whistle', 'index': 902}
# {'status': 'ok', 'result': '8.625652e-05', 'label': 'gazelle', 'index': 353}
# {'status': 'ok', 'result': '8.5855856e-05', 'label': 'burrito', 'index': 965}
# {'status': 'ok', 'result': '8.5558895e-06', 'label': 'bulbul', 'index': 16}
# {'status': 'ok', 'result': '8.531395e-05', 'label': 'dowitcher', 'index': 142}
# {'status': 'ok', 'result': '8.517305e-05', 'label': 'dome', 'index': 538}
# {'status': 'ok', 'result': '8.452957e-06', 'label': 'head_cabbage', 'index': 936}
# {'status': 'ok', 'result': '8.4450875e-07', 'label': 'patio', 'index': 706}
# {'status': 'ok', 'result': '8.442434e-05', 'label': 'sulphur_butterfly', 'index': 325}
# {'status': 'ok', 'result': '8.425323e-06', 'label': 'steel_arch_bridge', 'index': 821}
# {'status': 'ok', 'result': '8.4207546e-05', 'label': 'web_site', 'index': 916}
# {'status': 'ok', 'result': '8.387048e-06', 'label': 'broom', 'index': 462}
# {'status': 'ok', 'result': '8.3859384e-05', 'label': 'snail', 'index': 113}
# {'status': 'ok', 'result': '8.373535e-06', 'label': 'piggy_bank', 'index': 719}
# {'status': 'ok', 'result': '8.359557e-05', 'label': 'paddle', 'index': 693}
# {'status': 'ok', 'result': '8.3492065e-05', 'label': 'diaper', 'index': 529}
# {'status': 'ok', 'result': '8.348919e-05', 'label': 'orangutan', 'index': 365}
# {'status': 'ok', 'result': '8.3444735e-05', 'label': 'flute', 'index': 558}
# {'status': 'ok', 'result': '8.310326e-05', 'label': 'mosque', 'index': 668}
# {'status': 'ok', 'result': '8.294397e-06', 'label': 'scorpion', 'index': 71}
# {'status': 'ok', 'result': '8.283562e-06', 'label': 'bearskin', 'index': 439}
# {'status': 'ok', 'result': '8.2674494e-05', 'label': 'komondor', 'index': 228}
# {'status': 'ok', 'result': '8.2672625e-05', 'label': 'Rhodesian_ridgeback', 'index': 159}
# {'status': 'ok', 'result': '8.260396e-05', 'label': 'Irish_wolfhound', 'index': 170}
# {'status': 'ok', 'result': '8.257444e-05', 'label': 'catamaran', 'index': 484}
# {'status': 'ok', 'result': '8.220214e-05', 'label': 'fire_screen', 'index': 556}
# {'status': 'ok', 'result': '8.219684e-05', 'label': 'seashore', 'index': 978}
# {'status': 'ok', 'result': '8.208893e-05', 'label': 'monarch', 'index': 323}
# {'status': 'ok', 'result': '8.208486e-06', 'label': 'baseball', 'index': 429}
# {'status': 'ok', 'result': '8.194383e-05', 'label': 'quail', 'index': 85}
# {'status': 'ok', 'result': '8.166435e-06', 'label': 'analog_clock', 'index': 409}
# {'status': 'ok', 'result': '8.158795e-05', 'label': 'Model_T', 'index': 661}
# {'status': 'ok', 'result': '8.118859e-05', 'label': 'sturgeon', 'index': 394}
# {'status': 'ok', 'result': '8.1094964e-07', 'label': 'snowplow', 'index': 803}
# {'status': 'ok', 'result': '8.0773665e-05', 'label': 'nail', 'index': 677}
# {'status': 'ok', 'result': '8.073485e-07', 'label': 'wig', 'index': 903}
# {'status': 'ok', 'result': '8.068565e-05', 'label': 'squirrel_monkey', 'index': 382}
# {'status': 'ok', 'result': '8.054655e-05', 'label': 'pizza', 'index': 963}
# {'status': 'ok', 'result': '8.0306425e-05', 'label': 'bittern', 'index': 133}
# {'status': 'ok', 'result': '8.013678e-05', 'label': 'American_chameleon', 'index': 40}
# {'status': 'ok', 'result': '8.009298e-05', 'label': 'crib', 'index': 520}
# {'status': 'ok', 'result': '8.001286e-06', 'label': 'trench_coat', 'index': 869}
# {'status': 'ok', 'result': '7.990723e-05', 'label': 'fiddler_crab', 'index': 120}
# {'status': 'ok', 'result': '7.925972e-05', 'label': 'photocopier', 'index': 713}
# {'status': 'ok', 'result': '7.923938e-05', 'label': 'brass', 'index': 458}
# :-( [Errno 2] No such file or directory: ''
# Something went wrong could not convert string to float: 'Coul'
# Something went wrong could not convert string to float: 'Coul'
# Something went wrong could not convert string to float: 'Coul'
# :-( [Errno 2] No such file or directory: ''
# Something went wrong could not convert string to float: 'Coul'
# label_name: thimble
# label_index: 855
# max_value: 9.58
# min_value: 8.24
# average_total: 9.120000000000001
# average_top_three: 9.413333333333334
# total_dirs: 4
# --------------------
# sending guess for label thimble with synsnet n04423845
# Guess was wrong. Status code: 500. With message: b'Error: could not handle the request\n'
# answer correct: False
# Static ping 0.00022050082
# Static ping 0.00022049995
# Static ping 0.00022049995
# Static ping 0.00022049995
# Static ping 0.00022049995
# Static ping 0.00022049995
# Static ping 0.00022049995
# Static ping 0.00022050082
# Static ping 0.00022049995
# Static ping 0.00022049995
# Static ping 0.00022049995
# Static ping 0.00022049995
# Static ping 0.00022049995
# Static ping 0.00022049995
# Static ping 8.391156e-05
# Getting results...
# Got all single results. Total of 990 records.
# sorting list of results with 990 elements
# {'status': 'ok', 'result': '9.97888e-06', 'label': 'hartebeest', 'index': 351}
# {'status': 'ok', 'result': '9.97437e-07', 'label': 'hummingbird', 'index': 94}
# {'status': 'ok', 'result': '9.956683e-05', 'label': 'wine_bottle', 'index': 907}
# {'status': 'ok', 'result': '9.954628e-06', 'label': 'thimble', 'index': 855}
# {'status': 'ok', 'result': '9.953587e-05', 'label': 'washer', 'index': 897}
# {'status': 'ok', 'result': '9.904322e-05', 'label': 'Rhodesian_ridgeback', 'index': 159}
# {'status': 'ok', 'result': '9.901504e-05', 'label': 'Rottweiler', 'index': 234}
# {'status': 'ok', 'result': '9.885243e-06', 'label': 'power_drill', 'index': 740}
# {'status': 'ok', 'result': '9.85107e-05', 'label': 'seashore', 'index': 978}
# {'status': 'ok', 'result': '9.795585e-05', 'label': 'flagpole', 'index': 557}
# {'status': 'ok', 'result': '9.710018e-05', 'label': 'oxcart', 'index': 690}
# {'status': 'ok', 'result': '9.7021286e-05', 'label': 'wombat', 'index': 106}
# {'status': 'ok', 'result': '9.701868e-05', 'label': 'limousine', 'index': 627}
# {'status': 'ok', 'result': '9.6915915e-05', 'label': 'carbonara', 'index': 959}
# {'status': 'ok', 'result': '9.630764e-05', 'label': 'American_black_bear', 'index': 295}
# {'status': 'ok', 'result': '9.628403e-05', 'label': 'hornbill', 'index': 93}
# {'status': 'ok', 'result': '9.625103e-06', 'label': 'croquet_ball', 'index': 522}
# {'status': 'ok', 'result': '9.617094e-05', 'label': 'pillow', 'index': 721}
# {'status': 'ok', 'result': '9.6130236e-05', 'label': 'fox_squirrel', 'index': 335}
# {'status': 'ok', 'result': '9.592997e-05', 'label': 'four-poster', 'index': 564}
# {'status': 'ok', 'result': '9.586857e-05', 'label': 'packet', 'index': 692}
# {'status': 'ok', 'result': '9.514834e-06', 'label': 'table_lamp', 'index': 846}
# {'status': 'ok', 'result': '9.4833296e-05', 'label': 'African_chameleon', 'index': 47}
# {'status': 'ok', 'result': '9.4699564e-05', 'label': 'African_elephant', 'index': 386}
# {'status': 'ok', 'result': '9.462617e-05', 'label': 'monarch', 'index': 323}
# {'status': 'ok', 'result': '9.461582e-06', 'label': 'photocopier', 'index': 713}
# {'status': 'ok', 'result': '9.44858e-07', 'label': 'cinema', 'index': 498}
# {'status': 'ok', 'result': '9.4118026e-05', 'label': 'pedestal', 'index': 708}
# {'status': 'ok', 'result': '9.37719e-05', 'label': 'capuchin', 'index': 378}
# {'status': 'ok', 'result': '9.336783e-05', 'label': 'cassette_player', 'index': 482}
# {'status': 'ok', 'result': '9.332342e-06', 'label': 'box_turtle', 'index': 37}
# {'status': 'ok', 'result': '9.3059665e-05', 'label': 'water_bottle', 'index': 898}
# {'status': 'ok', 'result': '9.277083e-05', 'label': 'red-backed_sandpiper', 'index': 140}
# {'status': 'ok', 'result': '9.270946e-05', 'label': 'teapot', 'index': 849}
# {'status': 'ok', 'result': '9.245907e-05', 'label': 'West_Highland_white_terrier', 'index': 203}
# {'status': 'ok', 'result': '9.241358e-05', 'label': 'water_tower', 'index': 900}
# {'status': 'ok', 'result': '9.237767e-05', 'label': 'submarine', 'index': 833}
# {'status': 'ok', 'result': '9.225477e-05', 'label': 'Saluki', 'index': 176}
# {'status': 'ok', 'result': '9.2072156e-07', 'label': 'carton', 'index': 478}
# {'status': 'ok', 'result': '9.08682e-06', 'label': 'red_wine', 'index': 966}
# {'status': 'ok', 'result': '9.085081e-05', 'label': 'soccer_ball', 'index': 805}
# {'status': 'ok', 'result': '9.045565e-06', 'label': 'bathing_cap', 'index': 433}
# {'status': 'ok', 'result': '9.0411275e-05', 'label': 'tiger_shark', 'index': 3}
# {'status': 'ok', 'result': '9.0363965e-06', 'label': 'toyshop', 'index': 865}
# {'status': 'ok', 'result': '9.0272784e-05', 'label': 'flute', 'index': 558}
# {'status': 'ok', 'result': '8.9723195e-05', 'label': 'pier', 'index': 718}
# {'status': 'ok', 'result': '8.914246e-07', 'label': 'jigsaw_puzzle', 'index': 611}
# {'status': 'ok', 'result': '8.905181e-05', 'label': 'jackfruit', 'index': 955}
# {'status': 'ok', 'result': '8.897116e-07', 'label': 'barbell', 'index': 422}
# {'status': 'ok', 'result': '8.896171e-05', 'label': "potter's_wheel", 'index': 739}
# {'status': 'ok', 'result': '8.892227e-05', 'label': 'echidna', 'index': 102}
# {'status': 'ok', 'result': '8.836512e-05', 'label': 'golfcart', 'index': 575}
# {'status': 'ok', 'result': '8.830869e-05', 'label': 'spotted_salamander', 'index': 28}
# {'status': 'ok', 'result': '8.806929e-05', 'label': 'partridge', 'index': 86}
# {'status': 'ok', 'result': '8.80079e-05', 'label': 'Appenzeller', 'index': 240}
# {'status': 'ok', 'result': '8.768157e-05', 'label': 'banana', 'index': 954}
# {'status': 'ok', 'result': '8.763643e-06', 'label': 'otter', 'index': 360}
# {'status': 'ok', 'result': '8.7306825e-07', 'label': 'military_uniform', 'index': 652}
# {'status': 'ok', 'result': '8.715365e-05', 'label': 'cliff_dwelling', 'index': 500}
# {'status': 'ok', 'result': '8.711238e-06', 'label': 'otterhound', 'index': 175}
# {'status': 'ok', 'result': '8.691488e-05', 'label': 'Afghan_hound', 'index': 160}
# {'status': 'ok', 'result': '8.682374e-05', 'label': 'crash_helmet', 'index': 518}
# {'status': 'ok', 'result': '8.682043e-05', 'label': 'Italian_greyhound', 'index': 171}
# {'status': 'ok', 'result': '8.655168e-05', 'label': 'American_Staffordshire_terrier', 'index': 180}
# {'status': 'ok', 'result': '8.631147e-06', 'label': 'rock_python', 'index': 62}
# {'status': 'ok', 'result': '8.6113796e-05', 'label': 'affenpinscher', 'index': 252}
# {'status': 'ok', 'result': '8.560601e-06', 'label': 'meat_loaf', 'index': 962}
# {'status': 'ok', 'result': '8.54384e-05', 'label': 'platypus', 'index': 103}
# {'status': 'ok', 'result': '8.543196e-05', 'label': 'go-kart', 'index': 573}
# {'status': 'ok', 'result': '8.536871e-06', 'label': 'sundial', 'index': 835}
# {'status': 'ok', 'result': '8.5212025e-07', 'label': 'shopping_basket', 'index': 790}
# {'status': 'ok', 'result': '8.498195e-05', 'label': "jack-o'-lantern", 'index': 607}
# {'status': 'ok', 'result': '8.432951e-06', 'label': 'pay-phone', 'index': 707}
# {'status': 'ok', 'result': '8.391156e-05', 'label': 'accordion', 'index': 401}
# {'status': 'ok', 'result': '8.346334e-05', 'label': 'bald_eagle', 'index': 22}
# {'status': 'ok', 'result': '8.338805e-05', 'label': 'magpie', 'index': 18}
# {'status': 'ok', 'result': '8.335852e-05', 'label': 'hamster', 'index': 333}
# {'status': 'ok', 'result': '8.293895e-05', 'label': 'artichoke', 'index': 944}
# {'status': 'ok', 'result': '8.277774e-06', 'label': 'briard', 'index': 226}
# {'status': 'ok', 'result': '8.27565e-05', 'label': 'green_mamba', 'index': 64}
# {'status': 'ok', 'result': '8.2338345e-05', 'label': 'Japanese_spaniel', 'index': 152}
# {'status': 'ok', 'result': '8.2127866e-05', 'label': 'nematode', 'index': 111}
# {'status': 'ok', 'result': '8.20734e-05', 'label': 'bell_cote', 'index': 442}
# {'status': 'ok', 'result': '8.1869686e-05', 'label': 'ladybug', 'index': 301}
# {'status': 'ok', 'result': '8.154089e-05', 'label': 'half_track', 'index': 586}
# {'status': 'ok', 'result': '8.123566e-05', 'label': 'crate', 'index': 519}
# {'status': 'ok', 'result': '8.084005e-05', 'label': 'syringe', 'index': 845}
# {'status': 'ok', 'result': '8.068425e-06', 'label': 'sea_lion', 'index': 150}
# {'status': 'ok', 'result': '8.060355e-07', 'label': 'park_bench', 'index': 703}
# {'status': 'ok', 'result': '8.046828e-06', 'label': 'perfume', 'index': 711}
# {'status': 'ok', 'result': '8.024198e-05', 'label': 'seat_belt', 'index': 785}
# {'status': 'ok', 'result': '7.999486e-05', 'label': 'Petri_dish', 'index': 712}
# {'status': 'ok', 'result': '7.9298305e-05', 'label': 'toucan', 'index': 96}
# {'status': 'ok', 'result': '7.9004436e-05', 'label': 'streetcar', 'index': 829}
# {'status': 'ok', 'result': '7.888157e-06', 'label': 'pelican', 'index': 144}
# {'status': 'ok', 'result': '7.867497e-06', 'label': 'Sealyham_terrier', 'index': 190}
# {'status': 'ok', 'result': '7.85432e-05', 'label': 'anemone_fish', 'index': 393}
# {'status': 'ok', 'result': '7.834051e-05', 'label': 'boa_constrictor', 'index': 61}
# {'status': 'ok', 'result': '7.82275e-05', 'label': 'timber_wolf', 'index': 269}
# {'status': 'ok', 'result': '7.815719e-06', 'label': 'knot', 'index': 616}
# :-( [Errno 2] No such file or directory: ''
# Something went wrong could not convert string to float: 'Coul'
# :-( [Errno 2] No such file or directory: ''
# Something went wrong could not convert string to float: 'Coul'
# :-( [Errno 2] No such file or directory: ''
# Something went wrong could not convert string to float: 'Coul'
# Something went wrong could not convert string to float: 'Coul'
# Something went wrong could not convert string to float: 'Coul'
# :-( [Errno 2] No such file or directory: ''
# Something went wrong could not convert string to float: 'Coul'
# Something went wrong could not convert string to float: 'Coul'
# Something went wrong could not convert string to float: 'Coul'
# Something went wrong could not convert string to float: 'Coul'
# label_name: flute
# label_index: 558
# max_value: 9.21
# min_value: 5.29
# average_total: 8.102500000000001
# average_top_three: 9.040000000000001
# total_dirs: 4
# --------------------
# sending guess for label flute with synsnet n03372029
# Guess was wrong. Status code: 500. With message: b'Error: could not handle the request\n'
# answer correct: False
# Static ping 8.391156e-05
# Static ping 8.391156e-05
# Static ping 8.391156e-05
# Static ping 8.391156e-05
# Static ping 8.3911895e-05
# Static ping 8.391156e-05
# Static ping 8.391156e-05
# Static ping 8.391156e-05
# Static ping 9.363386e-05
# Getting results...
# Got all single results. Total of 992 records.
# sorting list of results with 992 elements
# {'status': 'ok', 'result': '9.9561934e-05', 'label': 'recreational_vehicle', 'index': 757}
# {'status': 'ok', 'result': '9.953789e-05', 'label': 'redbone', 'index': 168}
# {'status': 'ok', 'result': '9.9384786e-05', 'label': 'shoe_shop', 'index': 788}
# {'status': 'ok', 'result': '9.927324e-05', 'label': 'lens_cap', 'index': 622}
# {'status': 'ok', 'result': '9.914181e-07', 'label': 'harmonica', 'index': 593}
# {'status': 'ok', 'result': '9.886979e-08', 'label': 'shoji', 'index': 789}
# {'status': 'ok', 'result': '9.836711e-06', 'label': 'table_lamp', 'index': 846}
# {'status': 'ok', 'result': '9.804451e-06', 'label': 'house_finch', 'index': 12}
# {'status': 'ok', 'result': '9.802391e-05', 'label': 'tench', 'index': 0}
# {'status': 'ok', 'result': '9.764919e-05', 'label': 'snow_leopard', 'index': 289}
# {'status': 'ok', 'result': '9.730066e-05', 'label': 'rain_barrel', 'index': 756}
# {'status': 'ok', 'result': '9.683357e-08', 'label': 'slot', 'index': 800}
# {'status': 'ok', 'result': '9.584264e-05', 'label': 'gong', 'index': 577}
# {'status': 'ok', 'result': '9.552192e-06', 'label': 'American_lobster', 'index': 122}
# {'status': 'ok', 'result': '9.544597e-07', 'label': 'racket', 'index': 752}
# {'status': 'ok', 'result': '9.4642994e-05', 'label': 'cocker_spaniel', 'index': 219}
# {'status': 'ok', 'result': '9.460263e-05', 'label': 'Rottweiler', 'index': 234}
# {'status': 'ok', 'result': '9.4077484e-05', 'label': 'seat_belt', 'index': 785}
# {'status': 'ok', 'result': '9.3873015e-05', 'label': 'admiral', 'index': 321}
# {'status': 'ok', 'result': '9.38149e-06', 'label': 'trilobite', 'index': 69}
# {'status': 'ok', 'result': '9.364083e-06', 'label': 'Ibizan_hound', 'index': 173}
# {'status': 'ok', 'result': '9.363386e-05', 'label': 'accordion', 'index': 401}
# {'status': 'ok', 'result': '9.362118e-05', 'label': 'bookcase', 'index': 453}
# {'status': 'ok', 'result': '9.358605e-06', 'label': 'garden_spider', 'index': 74}
# {'status': 'ok', 'result': '9.358605e-06', 'label': 'black_and_gold_garden_spider', 'index': 72}
# {'status': 'ok', 'result': '9.338325e-05', 'label': 'hand-held_computer', 'index': 590}
# {'status': 'ok', 'result': '9.315169e-05', 'label': 'Irish_terrier', 'index': 184}
# {'status': 'ok', 'result': '9.308936e-05', 'label': 'capuchin', 'index': 378}
# {'status': 'ok', 'result': '9.300797e-05', 'label': 'toyshop', 'index': 865}
# {'status': 'ok', 'result': '9.288688e-06', 'label': 'rule', 'index': 769}
# {'status': 'ok', 'result': '9.269474e-06', 'label': 'bulbul', 'index': 16}
# {'status': 'ok', 'result': '9.232644e-05', 'label': 'racer', 'index': 751}
# {'status': 'ok', 'result': '9.2016795e-05', 'label': 'brambling', 'index': 10}
# {'status': 'ok', 'result': '9.2013564e-05', 'label': 'warthog', 'index': 343}
# {'status': 'ok', 'result': '9.191137e-07', 'label': 'oxygen_mask', 'index': 691}
# {'status': 'ok', 'result': '9.159859e-05', 'label': 'drumstick', 'index': 542}
# {'status': 'ok', 'result': '9.129066e-07', 'label': 'cleaver', 'index': 499}
# {'status': 'ok', 'result': '9.128747e-05', 'label': 'English_foxhound', 'index': 167}
# {'status': 'ok', 'result': '9.1003385e-05', 'label': 'barbershop', 'index': 424}
# {'status': 'ok', 'result': '9.0588543e-07', 'label': 'chain', 'index': 488}
# {'status': 'ok', 'result': '9.01422e-05', 'label': 'velvet', 'index': 885}
# {'status': 'ok', 'result': '9.0108326e-05', 'label': 'redshank', 'index': 141}
# {'status': 'ok', 'result': '8.98419e-07', 'label': 'shopping_basket', 'index': 790}
# {'status': 'ok', 'result': '8.983648e-05', 'label': 'necklace', 'index': 679}
# {'status': 'ok', 'result': '8.981686e-05', 'label': 'groenendael', 'index': 224}
# {'status': 'ok', 'result': '8.974069e-05', 'label': 'maypole', 'index': 645}
# {'status': 'ok', 'result': '8.9209e-05', 'label': 'cash_machine', 'index': 480}
# {'status': 'ok', 'result': '8.8803085e-05', 'label': 'espresso_maker', 'index': 550}
# {'status': 'ok', 'result': '8.878719e-06', 'label': 'Pekinese', 'index': 154}
# {'status': 'ok', 'result': '8.8520486e-05', 'label': 'liner', 'index': 628}
# {'status': 'ok', 'result': '8.847894e-05', 'label': 'hair_slide', 'index': 584}
# {'status': 'ok', 'result': '8.819725e-05', 'label': 'common_newt', 'index': 26}
# {'status': 'ok', 'result': '8.8073875e-07', 'label': 'bustard', 'index': 138}
# {'status': 'ok', 'result': '8.657869e-05', 'label': 'African_hunting_dog', 'index': 275}
# {'status': 'ok', 'result': '8.6095235e-05', 'label': 'thresher', 'index': 856}
# {'status': 'ok', 'result': '8.585294e-07', 'label': 'carton', 'index': 478}
# {'status': 'ok', 'result': '8.577887e-07', 'label': 'cinema', 'index': 498}
# {'status': 'ok', 'result': '8.573639e-05', 'label': 'head_cabbage', 'index': 936}
# {'status': 'ok', 'result': '8.568942e-05', 'label': 'sports_car', 'index': 817}
# {'status': 'ok', 'result': '8.5541e-06', 'label': 'Egyptian_cat', 'index': 285}
# {'status': 'ok', 'result': '8.546105e-05', 'label': 'crayfish', 'index': 124}
# {'status': 'ok', 'result': '8.541954e-05', 'label': 'soft-coated_wheaten_terrier', 'index': 202}
# {'status': 'ok', 'result': '8.5349995e-05', 'label': 'hermit_crab', 'index': 125}
# {'status': 'ok', 'result': '8.530894e-05', 'label': 'comic_book', 'index': 917}
# {'status': 'ok', 'result': '8.4884005e-07', 'label': 'waffle_iron', 'index': 891}
# {'status': 'ok', 'result': '8.475625e-06', 'label': 'grey_fox', 'index': 280}
# {'status': 'ok', 'result': '8.427409e-05', 'label': 'brass', 'index': 458}
# {'status': 'ok', 'result': '8.401011e-05', 'label': 'burrito', 'index': 965}
# {'status': 'ok', 'result': '8.3909195e-05', 'label': 'dung_beetle', 'index': 305}
# {'status': 'ok', 'result': '8.387716e-06', 'label': 'impala', 'index': 352}
# {'status': 'ok', 'result': '8.386461e-06', 'label': 'tripod', 'index': 872}
# {'status': 'ok', 'result': '8.384108e-05', 'label': 'flagpole', 'index': 557}
# {'status': 'ok', 'result': '8.3247236e-05', 'label': 'steam_locomotive', 'index': 820}
# {'status': 'ok', 'result': '8.3189865e-05', 'label': 'baseball', 'index': 429}
# {'status': 'ok', 'result': '8.314248e-06', 'label': 'parking_meter', 'index': 704}
# {'status': 'ok', 'result': '8.286774e-05', 'label': 'koala', 'index': 105}
# {'status': 'ok', 'result': '8.261638e-06', 'label': 'Leonberg', 'index': 255}
# {'status': 'ok', 'result': '8.242815e-05', 'label': 'hamster', 'index': 333}
# {'status': 'ok', 'result': '8.186965e-06', 'label': 'holster', 'index': 597}
# {'status': 'ok', 'result': '8.1840306e-05', 'label': 'bull_mastiff', 'index': 243}
# {'status': 'ok', 'result': '8.161348e-05', 'label': 'cradle', 'index': 516}
# {'status': 'ok', 'result': '8.139934e-05', 'label': 'tape_player', 'index': 848}
# {'status': 'ok', 'result': '8.095647e-06', 'label': 'broom', 'index': 462}
# {'status': 'ok', 'result': '8.08265e-06', 'label': 'buckeye', 'index': 990}
# {'status': 'ok', 'result': '8.0565354e-05', 'label': 'doormat', 'index': 539}
# {'status': 'ok', 'result': '8.049027e-06', 'label': 'remote_control', 'index': 761}
# {'status': 'ok', 'result': '7.964591e-06', 'label': 'eggnog', 'index': 969}
# {'status': 'ok', 'result': '7.950614e-05', 'label': 'entertainment_center', 'index': 548}
# {'status': 'ok', 'result': '7.939738e-05', 'label': 'bulletproof_vest', 'index': 465}
# {'status': 'ok', 'result': '7.9251375e-05', 'label': 'Bernese_mountain_dog', 'index': 239}
# {'status': 'ok', 'result': '7.883335e-05', 'label': 'black_stork', 'index': 128}
# {'status': 'ok', 'result': '7.850973e-05', 'label': 'soccer_ball', 'index': 805}
# {'status': 'ok', 'result': '7.8347766e-05', 'label': 'cassette_player', 'index': 482}
# {'status': 'ok', 'result': '7.794131e-05', 'label': 'Gordon_setter', 'index': 214}
# {'status': 'ok', 'result': '7.785838e-06', 'label': 'restaurant', 'index': 762}
# {'status': 'ok', 'result': '7.7618985e-05', 'label': 'jellyfish', 'index': 107}
# {'status': 'ok', 'result': '7.726254e-05', 'label': 'yawl', 'index': 914}
# {'status': 'ok', 'result': '7.72043e-06', 'label': 'snowmobile', 'index': 802}
# {'status': 'ok', 'result': '7.703497e-06', 'label': 'four-poster', 'index': 564}
# {'status': 'ok', 'result': '7.693288e-05', 'label': 'king_penguin', 'index': 145}
# Something went wrong could not convert string to float: 'Coul'
# Something went wrong could not convert string to float: 'Coul'
# :-( [Errno 2] No such file or directory: ''
# :-( [Errno 2] No such file or directory: ''
# Something went wrong could not convert string to float: 'Coul'
# Something went wrong could not convert string to float: 'Coul'
# Something went wrong could not convert string to float: 'Coul'
# Something went wrong could not convert string to float: 'Coul'
# Something went wrong could not convert string to float: 'Coul'
# label_name: recreational_vehicle
# label_index: 757
# max_value: 9.95
# min_value: 3.2
# average_total: 7.835
# average_top_three: 9.38
# total_dirs: 4
# --------------------
# sending guess for label recreational_vehicle with synsnet n04065272
# Guess was wrong. Status code: 500. With message: b'Error: could not handle the request\n'
# answer correct: False
# Static ping 6.313533e-05
# Static ping 6.313514e-05
# Static ping 6.313514e-05
# Static ping 6.313514e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [108], line 1
# ----> 1 lets_do_this()
#
# Cell In [107], line 5, in lets_do_this()
#       2 stop_looping = False
#       4 while stop_looping == False:
# ----> 5     ping_untill_other_response()
#       6     correct = calc_labels_and_send_request(False)
#       7     if correct:
#
# Cell In [106], line 39, in ping_untill_other_response()
#      37     if compare_result != current_result:
#      38         return True
# ---> 39     time.sleep(20) # wait 20 seconds before trying again
#      41 # If this returns false, something went completely wrong because in 30 minutes nothing changed?
#      42 return False
#
# KeyboardInterrupt:

# %%
for x in range(0, 1000):
    try:
        y = [x]
        print("doing " + str(x))
        get_adnvanced_data_by_index_list(y)
    except Exception as e:
        print(str(x) + " goes wrong " + str(e))
# Out:
# doing 0
# doing 1
# Something went wrong could not convert string to float: 'Coul'
# doing 2
# doing 3
# doing 4
# doing 5
# doing 6
# doing 7
# doing 8
# doing 9
# doing 10
# doing 11
# doing 12
# doing 13
# doing 14
# doing 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [114], line 5
#       3     y = [x]
#       4     print("doing " + str(x))
# ----> 5     get_adnvanced_data_by_index_list(y)
#       6 except Exception as e:
#       7     print(str(x) + " goes wrong " + str(e))
#
# Cell In [101], line 27, in get_adnvanced_data_by_index_list(index_list)
#      24 with ThreadPoolExecutor(max_workers=threads) as executor:
#      25     future_to_url = {executor.submit(get_advanced_label_data_by_index, char) for char in index_list}
# ---> 27     for future in concurrent.futures.as_completed(future_to_url):
#      28         try:
#      29             data = future.result()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2288.0_x64__qbz5n2kfra8p0\lib\concurrent\futures\_base.py:245, in as_completed(fs, timeout)
#     240     if wait_timeout < 0:
#     241         raise TimeoutError(
#     242                 '%d (of %d) futures unfinished' % (
#     243                 len(pending), total_futures))
# --> 245 waiter.event.wait(wait_timeout)
#     247 with waiter.lock:
#     248     finished = waiter.finished_futures
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2288.0_x64__qbz5n2kfra8p0\lib\threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2288.0_x64__qbz5n2kfra8p0\lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
y = [1]
get_adnvanced_data_by_index_list(y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [115], line 2
#       1 y = [1]
# ----> 2 get_adnvanced_data_by_index_list(y)
#
# Cell In [101], line 27, in get_adnvanced_data_by_index_list(index_list)
#      24 with ThreadPoolExecutor(max_workers=threads) as executor:
#      25     future_to_url = {executor.submit(get_advanced_label_data_by_index, char) for char in index_list}
# ---> 27     for future in concurrent.futures.as_completed(future_to_url):
#      28         try:
#      29             data = future.result()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2288.0_x64__qbz5n2kfra8p0\lib\concurrent\futures\_base.py:245, in as_completed(fs, timeout)
#     240     if wait_timeout < 0:
#     241         raise TimeoutError(
#     242                 '%d (of %d) futures unfinished' % (
#     243                 len(pending), total_futures))
# --> 245 waiter.event.wait(wait_timeout)
#     247 with waiter.lock:
#     248     finished = waiter.finished_futures
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2288.0_x64__qbz5n2kfra8p0\lib\threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2288.0_x64__qbz5n2kfra8p0\lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
print()
# Out:
# 9.0411275e-05

# %%
sc_float = float("9.0411275e-05")
formatted = format(sc_float, 'f')
print(formatted)
# Out:
# 0.000090
