# %%
import matplotlib.pyplot as plt 
import json

# %% [markdown]
# # Fire Hose

# %%
# The JSON code of the X and Y variables
json_string_fh_xy = '{"1": 11.5,"2": 18,"3": 24.5,"4": 31,"5": 37.5,"6": 44,"7": 50.5,"8": 57,"9": 63.5,"10": 70,"11": 76.5,"12": 83,"13": 89.5,"14": 96,"15": 102.5,"16": 109,"17": 115.5,"18": 122,"19": 128.5,"20": 135,"21": 141.5,"22": 148,"23": 154.5,"24": 161,"25": 167.5,"26": 174,"27": 180.5,"28": 187,"29": 193.5,"30": 200,"31": 206.5,"32": 213,"33": 219.5,"34": 226,"35": 232.5,"36": 239,"37": 245.5,"38": 252,"39": 258.5,"40": 265,"41": 271.5,"42": 278,"43": 284.5,"44": 291,"45": 297.5,"46": 304,"47": 310.5,"48": 317,"49": 323.5,"50": 330}'
json_fh_xy = json.loads(json_string_fh_xy)

x_fh_Array = [] # Where X is amount of trees
for i in range(50):
    x_fh_Array.append(i + 1)


y_fh_Array = [] # Where X is amount of trees
for i in range(50):
    y_fh_Array.append(json_fh_xy["" + str(i + 1)])

# %% [markdown]
# # Gardening hose

# %%
# The JSON code of the X and Y variables
json_string_gh_xy = '{"1": 12,"2": 21,"3": 30,"4": 39,"5": 48,"6": 57,"7": 66,"8": 75,"9": 84,"10": 93,"11": 102,"12": 111,"13": 120,"14": 129,"15": 138,"16": 147,"17": 156,"18": 165,"19": 174,"20": 183,"21": 192,"22": 201,"23": 210,"24": 219,"25": 228,"26": 237,"27": 246,"28": 255,"29": 264,"30": 273,"31": 282,"32": 291,"33": 300,"34": 309,"35": 318,"36": 327,"37": 336,"38": 345,"39": 354,"40": 363,"41": 372,"42": 381,"43": 390,"44": 399,"45": 408,"46": 417,"47": 426,"48": 435,"49": 444,"50": 453}'
json_gh_xy = json.loads(json_string_gh_xy)

x_gh_Array = [] # Where X is amount of trees
for i in range(50):
    x_gh_Array.append(i + 1)


y_gh_Array = [] # Where X is amount of trees
for i in range(50):
    y_gh_Array.append(json_gh_xy["" + str(i + 1)])

# %% [markdown]
# # Small Bottles

# %%
json_string_sb_xy = '{"1": 6,"2": 12,"3": 16,"4": 22,"5": 26,"6": 32,"7": 38,"8": 42,"9": 48,"10": 52,"11": 58,"12": 64,"13": 68,"14": 74,"15": 78,"16": 84,"17": 90,"18": 94,"19": 100,"20": 104,"21": 110,"22": 116,"23": 120,"24": 126,"25": 130,"26": 136}'
json_sb_xy = json.loads(json_string_sb_xy)

x_sb_Array = [] # Where X is amount of trees
for i in range(26):
    x_sb_Array.append(i + 1)


y_sb_Array = [] # Where X is amount of trees
for i in range(26):
    y_sb_Array.append(json_sb_xy["" + str(i + 1)])

# %% [markdown]
# # Big Bottles

# %%
json_string_bb_xy = '{"1": 10,"2": 14,"3": 24,"4": 28,"5": 32,"6": 42,"7": 46,"8": 50,"9": 60,"10": 64,"11": 74,"12": 78,"13": 82,"14": 92,"15": 96,"16": 100,"17": 110,"18": 114,"19": 124,"20": 128,"21": 132}'
json_bb_xy = json.loads(json_string_bb_xy)

x_bb_Array = [] # Where X is amount of trees
for i in range(21):
    x_bb_Array.append(i + 1)


y_bb_Array = [] # Where X is amount of trees
for i in range(21):
    y_bb_Array.append(json_bb_xy["" + str(i + 1)])

# %%
plt.plot(x_fh_Array, y_fh_Array, label = "Fire Hose")
plt.plot(x_gh_Array, y_gh_Array, label = "Gardening Hose")
plt.plot(x_sb_Array, y_sb_Array, label = "Small Bottles")
plt.plot(x_bb_Array, y_bb_Array, label = "Big Bottles")

plt.title('All waterers efficiency')
plt.legend()
plt.show()

# %%
show_untill_x = 2

plt.plot(x_fh_Array[0:show_untill_x], y_fh_Array[0:show_untill_x], label = "Fire Hose")
plt.plot(x_gh_Array[0:show_untill_x], y_gh_Array[0:show_untill_x], label = "Gardening Hose")
plt.plot(x_sb_Array[0:show_untill_x], y_sb_Array[0:show_untill_x], label = "Small Bottles")
plt.plot(x_bb_Array[0:show_untill_x], y_bb_Array[0:show_untill_x], label = "Big Bottles")

plt.title('All waterers efficiency')
plt.legend()
plt.show()

# %%
lines_combined = '{"1": 6,"2": 12,"3": 16,"4": 22,"5": 26,"6": 32,"7": 38,"8": 42,"9": 48,"10": 52,"11": 58,"12": 64,"13": 68,"14": 74,"15": 78,"16": 84,"17": 90,"18": 94,"19": 100,"20": 104,"21": 110,"22": 116,"23": 120,"24": 126,"25": 130,"26": 136,"27": 140,"28": 144,"29": 148,"30": 158,"31": 162,"32": 166,"33": 176,"34": 180,"35": 190,"36": 194,"37": 198,"38": 208,"39": 212,"40": 216,"41": 226,"42": 230,"43": 240,"44": 244,"45": 248,"46": 258,"47": 262,"48": 266,"49": 268.5,"50": 275}'
json_lines = json.loads(lines_combined)

lines_x = [] # Where X is amount of trees
for i in range(50):
    lines_x.append(i + 1)


lines_y = [] # Where X is amount of trees
for i in range(50):
    lines_y.append(json_lines["" + str(i + 1)])
    
plt.plot(lines_x, lines_y, label = "Lets Go Line")

plt.title('Small Bottles -> Big bottles -> Fire Hose')
plt.legend()
plt.show()

lines_with_gardening_hose = '{"1": 6,"2": 12,"3": 16,"4": 22,"5": 26,"6": 32,"7": 38,"8": 42,"9": 48,"10": 52,"11": 58,"12": 64,"13": 68,"14": 74,"15": 78,"16": 84,"17": 90,"18": 94,"19": 100,"20": 104,"21": 110,"22": 116,"23": 120,"24": 126,"25": 130,"26": 136,"27": 140,"28": 144,"29": 148,"30": 158,"31": 162,"32": 166,"33": 176,"34": 180,"35": 190,"36": 194,"37": 198,"38": 208,"39": 212,"40": 216,"41": 226,"42": 230,"43": 240,"44": 244,"45": 248,"46": 258,"47": 262,"48": 266,"49": 273,"50": 282}'

# %% [markdown]
# # Scenario
#
# Je bent bijna klaar met de big bottles wateren
#
# De fire hose moet sowieso toch gepakt worden
